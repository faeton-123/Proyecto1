# %%
import numpy as np
import pandas as pd # python hace lo que hace R

# %%
data = np.load('data')

# %%
df = pd.DataFrame(data, columns =['SalePrice: ', 'OverallQual: ','1stFlrSF: ','TotRmsAbvGrd: ', 'YearBuilt: ', 'LotFrontage: '])

# %%
df
# Out:
#       SalePrice:   OverallQual:   1stFlrSF:   TotRmsAbvGrd:   YearBuilt:   \
# 0        208500.0            7.0       856.0             8.0       2003.0
# 1        181500.0            6.0      1262.0             6.0       1976.0
# 2        223500.0            7.0       920.0             6.0       2001.0
# 3        140000.0            7.0       961.0             7.0       1915.0
# 4        250000.0            8.0      1145.0             9.0       2000.0
# ...           ...            ...         ...             ...          ...
# 1455     175000.0            6.0       953.0             7.0       1999.0
# 1456     210000.0            6.0      2073.0             7.0       1978.0
# 1457     266500.0            7.0      1188.0             9.0       1941.0
# 1458     142125.0            5.0      1078.0             5.0       1950.0
# 1459     147500.0            5.0      1256.0             6.0       1965.0
#
#       LotFrontage:
# 0              65.0
# 1              80.0
# 2              68.0
# 3              60.0
# 4              84.0
# ...             ...
# 1455           62.0
# 1456           85.0
# 1457           66.0
# 1458           68.0
# 1459           75.0
#
# [1460 rows x 6 columns]

# %%
import numpy as np
import pandas as pd

# %%
data = np.load('data.npy')
df = pd.DataFrame(data, columns =['SalePrice: ', 'OverallQual: ','1stFlrSF: ','TotRmsAbvGrd: ', 'YearBuilt: ', 'LotFrontage: '])

# %%
n=len(df)
n_80 = int(n*0.8)
data_80 = df.iloc[:n_80, :]
data_80
# Out:
#       SalePrice:   OverallQual:   1stFlrSF:   TotRmsAbvGrd:   YearBuilt:   \
# 0        208500.0            7.0       856.0             8.0       2003.0
# 1        181500.0            6.0      1262.0             6.0       1976.0
# 2        223500.0            7.0       920.0             6.0       2001.0
# 3        140000.0            7.0       961.0             7.0       1915.0
# 4        250000.0            8.0      1145.0             9.0       2000.0
# ...           ...            ...         ...             ...          ...
# 1163     108959.0            4.0      1258.0             6.0       1969.0
# 1164     194000.0            5.0      1432.0             5.0       1978.0
# 1165     233170.0            7.0      1502.0             7.0       2009.0
# 1166     245350.0            8.0      1694.0             7.0       2008.0
# 1167     173000.0            6.0       959.0             7.0       2000.0
#
#       LotFrontage:
# 0              65.0
# 1              80.0
# 2              68.0
# 3              60.0
# 4              84.0
# ...             ...
# 1163           60.0
# 1164            NaN
# 1165           79.0
# 1166           64.0
# 1167           58.0
#
# [1168 rows x 6 columns]

# %%
media_columna = np.mean(data[:, 1])
media_columna
# Out:
# 6.0993150684931505
